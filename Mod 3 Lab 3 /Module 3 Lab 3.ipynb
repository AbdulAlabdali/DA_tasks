# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/Users/abdulrahmanalabdali/Desktop/iris-data.csv')
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        49
# Iris-versicolor    45
# versicolor          5
# Iris-setossa        1
# Name: class, dtype: int64

# %%
df.loc[(df['class']=='Iris-setossa'), 'class']='Iris-setosa'

# %%
df.loc[(df['class']=='versicolor'), 'class']='Iris-versicolor'

# %%
df['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
df.loc[df["petal_width_cm"].isna()]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
(df.groupby('class')['petal_width_cm']).mean()
# Out:
# class
# Iris-setosa        0.251111
# Iris-versicolor    1.326000
# Iris-virginica     2.034000
# Name: petal_width_cm, dtype: float64

# %%
df.loc[(df["petal_width_cm"].isnull()),"petal_width_cm"]=0.25

# %%
df.isnull().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# class              0
# dtype: int64

# %%
df.loc[df["sepal_length_cm"]<4]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77            0.067             3.0              5.0             1.7
# 78            0.060             2.9              4.5             1.5
# 79            0.057             2.6              3.5             1.0
# 80            0.055             2.4              3.8             1.1
# 81            0.055             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
df.loc[df["sepal_length_cm"]<4,"sepal_length_cm"]=np.nan
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df.loc[df["sepal_length_cm"].isna()]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 77              NaN             3.0              5.0             1.7
# 78              NaN             2.9              4.5             1.5
# 79              NaN             2.6              3.5             1.0
# 80              NaN             2.4              3.8             1.1
# 81              NaN             2.4              3.7             1.0
#
#               class
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       145.000000      150.000000       150.000000      150.000000
# mean          5.837241        3.054667         3.758667        1.203667
# std           0.813936        0.433123         1.764420        0.763252
# min           4.400000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df.loc[df["sepal_length_cm"].isna(),"sepal_length_cm"]=5.84

# %%
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.837333        3.054667         3.758667        1.203667
# std           0.800163        0.433123         1.764420        0.763252
# min           4.400000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
df.to_csv('iris_clean.csv')
