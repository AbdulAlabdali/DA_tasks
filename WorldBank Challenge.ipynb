# %%
pip install wbgapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-07-20
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
business = wb.data.DataFrame('IC.REG.DURS', wb.region.members('ECS'))

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:3] 
ax = business.T.plot(color='lightgray', legend=False) 
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
wb.series.info(q="J")
# Out:
# id                    value
# --------------------  -----------------------------------------------------------------------------------------------------------------------------------
# DC.DAC.JPNL.CD        Net bilateral aid flows from DAC donors, Japan (current US$)
# IP.JRN.ARTC.SC        Scientific and technical journal articles
# NY.ADJ.AEDU.CD        Adjusted savings: education expenditure (current US$)
# NY.ADJ.AEDU.GN.ZS     Adjusted savings: education expenditure (% of GNI)
# NY.ADJ.DCO2.CD        Adjusted savings: carbon dioxide damage (current US$)
# NY.ADJ.DCO2.GN.ZS     Adjusted savings: carbon dioxide damage (% of GNI)
# NY.ADJ.DFOR.CD        Adjusted savings: net forest depletion (current US$)
# NY.ADJ.DFOR.GN.ZS     Adjusted savings: net forest depletion (% of GNI)
# NY.ADJ.DKAP.CD        Adjusted savings: consumption of fixed capital (current US$)
# NY.ADJ.DKAP.GN.ZS     Adjusted savings: consumption of fixed capital (% of GNI)
# ...

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
business = wb.data.DataFrame('SH.STA.TRAF.P5',["SAU","DZA","IND","FRA","NGA"], time=range(2012,2020))
business
# Out:
#          YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  YR2019
# economy
# DZA        21.4    21.1    21.2    21.2    21.1    21.0    21.0    20.9
# FRA         5.9     5.3     5.4     5.5     5.5     5.5     5.2     5.1
# IND        17.6    17.0    16.1    15.6    15.3    15.2    15.5    15.6
# NGA        22.1    22.0    21.9    21.4    21.4    21.1    20.9    20.7
# SAU        27.0    26.3    25.0    26.2    28.7    30.6    33.2    35.9

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:5] 
ax = business.T.plot(color='lightgray', legend=False) 
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Interpretation
# - The latest data that could be found for this process is pertaining to yr 2019
# - Between 2012 and 2019 CHE and HTI is constant
# - SAU process improved 366% between 2012 and 2019
# - PAK process improved 160% between 2012 and 2019
