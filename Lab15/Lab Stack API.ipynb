# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import requests
import json

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
response=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response.json())
# Out:
# {'items': [{'tags': ['javascript', 'ios', 'react-native', 'yelp-fusion-api'], 'owner': {'account_id': 25169009, 'reputation': 1, 'user_id': 19012084, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/5397f234f35f15a6532e1f44c779b83f?s=256&d=identicon&r=PG', 'display_name': 'lawrencelu0904', 'link': 'https://stackoverflow.com/users/19012084/lawrencelu0904'}, 'is_answered': False, 'view_count': 58, 'answer_count': 2, 'score': 0, 'last_activity_date': 1661006801, 'creation_date': 1660834821, 'last_edit_date': 1661005961, 'question_id': 73405317, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73405317/undefined-is-not-an-object-filter-data-from-apis', 'title': 'Undefined is not an Object? (filter data from API&#39;s)'}, {'tags': ['java'], 'owner': {'account_id': 22573345, 'reputation': 7, 'user_id': 16759221, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjvG4DeKw4aRNsSyaWyupKVwNIj1SdGuUnfbxDbzAY=k-s256', 'display_name': 'Gianluca Vella', 'link': 'https://stackoverflow.com/users/16759221/gianluca-vella'}, 'is_answered': False, 'view_count': 32, 'closed_date': 1661006300, 'answer_count': 0, 'score': -1, 'last_activity_date': 1661006797, 'creation_date': 1661005541, 'last_edit_date': 1661006797, 'question_id': 73427477, 'link': 'https://stackoverflow.com/questions/73427477/adding-a-pointing-system-with-java', 'closed_reason': 'Needs details or clarity', 'title': 'Adding a pointing system with java'}, {'tags': ['javascript', 'calculator'], 'owner': {'account_id': 25464377, 'reputation': 11, 'user_id': 19263651, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwjRJ1rHVP_pOlTqn4RxOPxQLTGlhbYMwW_6NcP=k-s256', 'display_name': 'jason', 'link': 'https://stackoverflow.com/users/19263651/jason'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1661006797, 'creation_date': 1661006797, 'question_id': 73427613, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73427613/add-two-digits-js-calculator', 'title': 'Add two digits js calculator'}, {'tags': ['github', 'markdown', 'documentation', 'docusaurus'], 'owner': {'account_id': 23235251, 'reputation': 1, 'user_id': 17325336, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/de237f8526a36be69aa6b6444c54e07f?s=256&d=identicon&r=PG', 'display_name': 'Rishi', 'link': 'https://stackoverflow.com/users/17325336/rishi'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1661006793, 'creation_date': 1661006793, 'question_id': 73427612, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73427612/docusaurus-cannot-link-md-files-to-one-another-without-removing-file-extension', 'title': 'Docusaurus Cannot link .md files to one another without removing file extension'}, {'tags': ['c++', 'opengl', 'glfw'], 'owner': {'account_id': 22634178, 'reputation': 23, 'user_id': 16811187, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/42fafc3bb382da5d6c29fd3b8086b7c7?s=256&d=identicon&r=PG&f=1', 'display_name': 'ZT_31', 'link': 'https://stackoverflow.com/users/16811187/zt-31'}, 'is_answered': True, 'view_count': 38, 'answer_count': 1, 'score': 1, 'last_activity_date': 1661006792, 'creation_date': 1660888650, 'last_edit_date': 1660915502, 'question_id': 73412409, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73412409/opengl-not-rendering-triangle-from-vertex-buffer', 'title': 'OpenGL not rendering triangle from vertex buffer'}, {'tags': ['c++', 'assembly'], 'owner': {'account_id': 22395695, 'reputation': 1, 'user_id': 16607006, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJztjWr4L1txvHrHpveCYN0CHLFXag1oRvFx7gsZ=k-s256', 'display_name': 'gx1 moh', 'link': 'https://stackoverflow.com/users/16607006/gx1-moh'}, 'is_ans ...

# %%
results=(response.json())
res=response.json()
l=res["items"]
l
# Out:
# [{'tags': ['javascript', 'ios', 'react-native', 'yelp-fusion-api'],
#   'owner': {'account_id': 25169009,
#    'reputation': 1,
#    'user_id': 19012084,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/5397f234f35f15a6532e1f44c779b83f?s=256&d=identicon&r=PG',
#    'display_name': 'lawrencelu0904',
#    'link': 'https://stackoverflow.com/users/19012084/lawrencelu0904'},
#   'is_answered': False,
#   'view_count': 58,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1661006801,
#   'creation_date': 1660834821,
#   'last_edit_date': 1661005961,
#   'question_id': 73405317,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73405317/undefined-is-not-an-object-filter-data-from-apis',
#   'title': 'Undefined is not an Object? (filter data from API&#39;s)'},
#  {'tags': ['java'],
#   'owner': {'account_id': 22573345,
#    'reputation': 7,
#    'user_id': 16759221,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjvG4DeKw4aRNsSyaWyupKVwNIj1SdGuUnfbxDbzAY=k-s256',
#    'display_name': 'Gianluca Vella',
#    'link': 'https://stackoverflow.com/users/16759221/gianluca-vella'},
#   'is_answered': False,
#   'view_count': 32,
#   'closed_date': 1661006300,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1661006797,
#   'creation_date': 1661005541,
#   'last_edit_date': 1661006797,
#   'question_id': 73427477,
#   'link': 'https://stackoverflow.com/questions/73427477/adding-a-pointing-system-with-java',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'Adding a pointing system with java'},
#  {'tags': ['javascript', 'calculator'],
#   'owner': {'account_id': 25464377,
#    'reputation': 11,
#    'user_id': 19263651,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwjRJ1rHVP_pOlTqn4RxOPxQLTGlhbYMwW_6NcP=k-s256',
#    'display_name': 'jason',
#    'link': 'https://stackoverflow.com/users/19263651/jason'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006797,
#   'creation_date': 1661006797,
#   'question_id': 73427613,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427613/add-two-digits-js-calculator',
#   'title': 'Add two digits js calculator'},
#  {'tags': ['github', 'markdown', 'documentation', 'docusaurus'],
#   'owner': {'account_id': 23235251,
#    'reputation': 1,
#    'user_id': 17325336,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/de237f8526a36be69aa6b6444c54e07f?s=256&d=identicon&r=PG',
#    'display_name': 'Rishi',
#    'link': 'https://stackoverflow.com/users/17325336/rishi'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006793,
#   'creation_date': 1661006793,
#   'question_id': 73427612,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427612/docusaurus-cannot-link-md-files-to-one-another-without-removing-file-extension',
#   'title': 'Docusaurus Cannot link .md files to one another without removing file extension'},
#  {'tags': ['c++', 'opengl', 'glfw'],
#   'owner': {'account_id': 22634178,
#    'reputation': 23,
#    'user_id': 16811187,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/42fafc3bb382da5d6c29fd3b8086b7c7?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'ZT_31',
#    'link': 'https://stackoverflow.com/users/16811187/zt-31'},
#   'is_answered': True,
#   'view_count': 38,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1661006792,
#   'creation_date': 1660888650,
#   'last_edit_date': 1660915502,
#   'question_id': 73412409,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73412409/opengl-not-rendering-triangle-from-vertex-buffer',
#   'title': 'OpenGL not rendering triangle from vertex buffer'},
#  {'tags': ['c++', 'assembly'],
#   'owner': {'account_id': 22395695,
#    'reputation': 1,
#    'user_id': 16607006,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJztjWr4L1txvHrHpveCYN0CHLFXag1oRvFx7gsZ=k-s256',
#    'display_name': 'gx1 moh',
#    'link': 'https://stackoverflow.com/users/16607006/gx1-moh'},
#   'is_answered': False,
#   'view_count': 25,
#   'closed_date': 1661005782,
#   'answer_count': 0,
#   'score': -5,
#   'last_activity_date': 1661006779,
#   'creation_date': 1661005552,
#   'last_edit_date': 1661006779,
#   'question_id': 73427479,
#   'link': 'https://stackoverflow.com/questions/73427479/when-i-run-the-game-i-see-this-can-u-help-me-guys',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'When I Run The Game I See This , Can U Help me Guys'},
#  {'tags': ['javascript'],
#   'owner': {'account_id': 26115758,
#    'reputation': 1,
#    'user_id': 19808931,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/863261834647424/picture?type=large',
#    'display_name': 'Lazar Panović',
#    'link': 'https://stackoverflow.com/users/19808931/lazar-panovi%c4%87'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006779,
#   'creation_date': 1661006779,
#   'question_id': 73427611,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427611/how-can-i-save-buttons-in-variable-created-by-element-insertadjacenthtml-meth',
#   'title': 'How can I save buttons in variable, created by Element.insertAdjacentHTML() method?'},
#  {'tags': ['python', 'tkinter'],
#   'owner': {'account_id': 24858756,
#    'reputation': 1,
#    'user_id': 18734790,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/3326a748728ec4b0cc3b3f13cce62676?s=256&d=identicon&r=PG',
#    'display_name': 'Suliman',
#    'link': 'https://stackoverflow.com/users/18734790/suliman'},
#   'is_answered': False,
#   'view_count': 24,
#   'closed_date': 1661006462,
#   'answer_count': 0,
#   'score': -4,
#   'last_activity_date': 1661006772,
#   'creation_date': 1661005170,
#   'last_edit_date': 1661006772,
#   'question_id': 73427443,
#   'link': 'https://stackoverflow.com/questions/73427443/how-can-i-solve-this-proplem-with-python-tkniter',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'how can i solve this proplem with python tkniter'},
#  {'tags': ['java',
#    'multithreading',
#    'java.util.concurrent',
#    'concurrenthashmap',
#    'javaagents'],
#   'owner': {'account_id': 24236396,
#    'reputation': 84,
#    'user_id': 18189469,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/fjHuq.png?s=256&g=1',
#    'display_name': 'WobbleMeister',
#    'link': 'https://stackoverflow.com/users/18189469/wobblemeister'},
#   'is_answered': False,
#   'view_count': 35,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661006772,
#   'creation_date': 1660985821,
#   'last_edit_date': 1660999813,
#   'question_id': 73425360,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73425360/concurrenthashmap-of-string-concurrentlinkedqueue-pairs-not-consistently-regi',
#   'title': 'ConcurrentHashMap of &lt;String, ConcurrentLinkedQueue&gt; pairs not consistently registering additions'},
#  {'tags': ['java'],
#   'owner': {'account_id': 26115706,
#    'reputation': 1,
#    'user_id': 19808890,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucqDz1hyY5AlD_VMLtmCyKoaLFVYStF0Hbntaoqe=k-s256',
#    'display_name': 'Joejean Subsuban',
#    'link': 'https://stackoverflow.com/users/19808890/joejean-subsuban'},
#   'is_answered': False,
#   'view_count': 16,
#   'closed_date': 1661006768,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1661006771,
#   'creation_date': 1661006355,
#   'last_edit_date': 1661006771,
#   'question_id': 73427569,
#   'link': 'https://stackoverflow.com/questions/73427569/character-input-concern',
#   'closed_reason': 'Duplicate',
#   'title': 'Character Input Concern'},
#  {'tags': ['simics'],
#   'owner': {'account_id': 9932088,
#    'reputation': 1,
#    'user_id': 7351664,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/a093ad741654cfb950ba208bd3eb595c?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Chuck_Berry',
#    'link': 'https://stackoverflow.com/users/7351664/chuck-berry'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006769,
#   'creation_date': 1661006769,
#   'question_id': 73427609,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427609/is-simics-vxmon-ko-module-available-for-latest-ubuntu-version',
#   'title': 'is simics vxmon.ko module available for latest Ubuntu version?'},
#  {'tags': ['r', 'parsing', 'split'],
#   'owner': {'account_id': 35725,
#    'reputation': 5502,
#    'user_id': 101289,
#    'user_type': 'registered',
#    'accept_rate': 100,
#    'profile_image': 'https://i.stack.imgur.com/XiDX2.jpg?s=256&g=1',
#    'display_name': 'Abdel',
#    'link': 'https://stackoverflow.com/users/101289/abdel'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1661006761,
#   'creation_date': 1661004667,
#   'question_id': 73427387,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427387/r-split-column-into-the-numbers-it-contains-with-the-words-that-follow-as-colum',
#   'title': 'R: split column into the numbers it contains with the words that follow as column names'},
#  {'tags': ['kotlin', 'case', 'kotlin-when'],
#   'owner': {'account_id': 2868776,
#    'reputation': 19510,
#    'user_id': 2462531,
#    'user_type': 'registered',
#    'accept_rate': 40,
#    'profile_image': 'https://i.stack.imgur.com/oQIzz.jpg?s=256&g=1',
#    'display_name': 'Shailendra Madda',
#    'link': 'https://stackoverflow.com/users/2462531/shailendra-madda'},
#   'is_answered': True,
#   'view_count': 1002,
#   'accepted_answer_id': 63378572,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1661006759,
#   'creation_date': 1597238849,
#   'last_edit_date': 1661006759,
#   'question_id': 63377560,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/63377560/when-condition-with-ignore-case-in-kotlin',
#   'title': 'when condition with ignore case in kotlin'},
#  {'tags': ['laravel', 'vue.js', 'vite'],
#   'owner': {'account_id': 26115671,
#    'reputation': 1,
#    'user_id': 19808863,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmkRVrwwHC7uCnEN-0tgWar21uNECG8Wi9SLWKuS=k-s256',
#    'display_name': 'max devis',
#    'link': 'https://stackoverflow.com/users/19808863/max-devis'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661006752,
#   'creation_date': 1661005769,
#   'question_id': 73427499,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427499/referenceerror-cannot-access-services-before-initialization-vue-3-and-vite',
#   'title': 'ReferenceError: Cannot access &#39;Services&#39; before initialization vue 3 and vite'},
#  {'tags': ['php', 'wordpress', 'plugins'],
#   'owner': {'account_id': 22554122,
#    'reputation': 1,
#    'user_id': 16742799,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiYmt8WMutjHd5CQeSsGT3091yMeoHwwRuSQcsafw=k-s256',
#    'display_name': 'Umair Imtiaz',
#    'link': 'https://stackoverflow.com/users/16742799/umair-imtiaz'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661006749,
#   'creation_date': 1660995655,
#   'question_id': 73426402,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73426402/how-to-select-by-category-name-with-wordpress-query',
#   'title': 'How to select by category name with WordPress query'},
#  {'tags': ['php', 'json', 'foreach'],
#   'owner': {'account_id': 25827628,
#    'reputation': 11,
#    'user_id': 19565409,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/389b81bc0535b0006bed0986e9438fe7?s=256&d=identicon&r=PG',
#    'display_name': 'anderson',
#    'link': 'https://stackoverflow.com/users/19565409/anderson'},
#   'is_answered': True,
#   'view_count': 25,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1661006738,
#   'creation_date': 1660998717,
#   'question_id': 73426720,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73426720/array-splice-on-json-array-in-php',
#   'title': 'array_splice on JSON array in php'},
#  {'tags': ['string', 'binary'],
#   'owner': {'account_id': 11246508,
#    'reputation': 33,
#    'user_id': 8249235,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/7Qent.jpg?s=256&g=1',
#    'display_name': 'Parfen',
#    'link': 'https://stackoverflow.com/users/8249235/parfen'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006729,
#   'creation_date': 1661006729,
#   'question_id': 73427606,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427606/integer-literal-11111111111111111111111111111101-overflows-when-stored-into-i',
#   'title': 'Integer literal &#39;11111111111111111111111111111101&#39; overflows when stored into &#39;Int&#39;'},
#  {'tags': ['java', 'android', 'bluetooth'],
#   'owner': {'account_id': 26109074,
#    'reputation': 1,
#    'user_id': 19803316,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/8d28c42d02d9644d0e781dc46a0516ad?s=256&d=identicon&r=PG',
#    'display_name': 'Schurkee',
#    'link': 'https://stackoverflow.com/users/19803316/schurkee'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661006728,
#   'creation_date': 1660924291,
#   'question_id': 73419310,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73419310/app-crashes-at-onactivityresult-api-31-bluetooth',
#   'title': 'App crashes at onActivityResult() api 31 Bluetooth'},
#  {'tags': ['sql', 'database', 'sqlite'],
#   'owner': {'account_id': 26059722,
#    'reputation': 1,
#    'user_id': 19761280,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/bfd62ab8630e824f43bcfb70b06e84f6?s=256&d=identicon&r=PG',
#    'display_name': 'Sean',
#    'link': 'https://stackoverflow.com/users/19761280/sean'},
#   'is_answered': False,
#   'view_count': 11,
#   'closed_date': 1661006681,
#   'answer_count': 0,
#   'score': -3,
#   'last_activity_date': 1661006720,
#   'creation_date': 1661006406,
#   'last_edit_date': 1661006720,
#   'question_id': 73427573,
#   'link': 'https://stackoverflow.com/questions/73427573/please-how-will-i-print-out-the-output-of-this-program',
#   'closed_reason': 'Needs details or clarity',
#   'title': 'please how will i print out the output of this program'},
#  {'tags': ['java'],
#   'owner': {'account_id': 7413250,
#    'reputation': 573,
#    'user_id': 5639961,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/V2RDo.jpg?s=256&g=1',
#    'display_name': 'yyyy',
#    'link': 'https://stackoverflow.com/users/5639961/yyyy'},
#   'is_answered': False,
#   'view_count': 4,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006715,
#   'creation_date': 1661006715,
#   'question_id': 73427605,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427605/how-do-i-set-locale-to-en-us-when-testing-openjdk-on-cygwin',
#   'title': 'How do I set locale to en_US when testing OpenJDK on Cygwin?'},
#  {'tags': ['c#',
#    'post',
#    'json.net',
#    'deserialization',
#    'x-www-form-urlencoded'],
#   'owner': {'account_id': 432725,
#    'reputation': 6964,
#    'user_id': 817659,
#    'user_type': 'registered',
#    'accept_rate': 57,
#    'profile_image': 'https://www.gravatar.com/avatar/dc6960319324ecebe786580dfca13f07?s=256&d=identicon&r=PG',
#    'display_name': 'Ivan',
#    'link': 'https://stackoverflow.com/users/817659/ivan'},
#   'is_answered': True,
#   'view_count': 33,
#   'accepted_answer_id': 73421954,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1661006704,
#   'creation_date': 1660938461,
#   'question_id': 73421601,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73421601/json-string-to-parameters-to-post',
#   'title': 'json string to parameters to POST'},
#  {'tags': ['java', 'optional', 'record', 'java-17'],
#   'owner': {'account_id': 15875847,
#    'reputation': 3775,
#    'user_id': 11455105,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-jPwYiUfnicM/AAAAAAAAAAI/AAAAAAAASEw/uL-N0UuPi_U/photo.jpg?sz=256',
#    'display_name': 'Amal K',
#    'link': 'https://stackoverflow.com/users/11455105/amal-k'},
#   'is_answered': True,
#   'view_count': 94,
#   'answer_count': 1,
#   'score': 2,
#   'last_activity_date': 1661006695,
#   'creation_date': 1660977769,
#   'last_edit_date': 1660986617,
#   'question_id': 73424610,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73424610/optionalt-as-a-record-parameter-in-java',
#   'title': 'Optional&lt;T&gt; as a Record Parameter in Java'},
#  {'tags': ['pyspark', 'apache-spark-sql'],
#   'owner': {'account_id': 24012880,
#    'reputation': 13,
#    'user_id': 17996233,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c31f88dc083692ec9d3b30d1061b2ea7?s=256&d=identicon&r=PG',
#    'display_name': 'RLH',
#    'link': 'https://stackoverflow.com/users/17996233/rlh'},
#   'is_answered': True,
#   'view_count': 30,
#   'accepted_answer_id': 73403730,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1661006685,
#   'creation_date': 1660824256,
#   'last_edit_date': 1661006685,
#   'question_id': 73402786,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73402786/how-to-create-many-tables-programatically',
#   'title': 'How to create many tables programatically?'},
#  {'tags': ['c++', 'recursion'],
#   'owner': {'account_id': 26115629,
#    'reputation': 1,
#    'user_id': 19808827,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmmUkNYx2yUkrHYqfZ6JhwwJ4tpGERFaMshlBmFK=k-s256',
#    'display_name': 'santino',
#    'link': 'https://stackoverflow.com/users/19808827/santino'},
#   'is_answered': False,
#   'view_count': 24,
#   'closed_date': 1661006381,
#   'answer_count': 0,
#   'score': -2,
#   'last_activity_date': 1661006685,
#   'creation_date': 1661005262,
#   'last_edit_date': 1661006100,
#   'question_id': 73427453,
#   'link': 'https://stackoverflow.com/questions/73427453/what-is-the-difference-when-i-write-a-recursive-function-with-a-return-statement',
#   'closed_reason': 'Duplicate',
#   'title': 'What is the difference when I write a recursive function with a return statement and one without it'},
#  {'tags': ['node.js', 'macos', 'visual-studio-code', 'discord'],
#   'owner': {'account_id': 20372908,
#    'reputation': 49,
#    'user_id': 14944747,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/e38990a69d43f5b5146d3cd2c27eb7cb?s=256&d=identicon&r=PG',
#    'display_name': 'macandcheese-spaghetti',
#    'link': 'https://stackoverflow.com/users/14944747/macandcheese-spaghetti'},
#   'is_answered': False,
#   'view_count': 10,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006672,
#   'creation_date': 1661004519,
#   'last_edit_date': 1661006672,
#   'question_id': 73427370,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427370/timeout-error-running-a-discord-bot-in-node-js',
#   'title': 'Timeout error running a discord bot in node.js'},
#  {'tags': ['php', 'codeigniter'],
#   'owner': {'account_id': 26115763,
#    'reputation': 1,
#    'user_id': 19808937,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucoyb-Cuq5z2iNo_njFGstWEgPa9OZqxu5DNKBIvyw=k-s256',
#    'display_name': 'Muhammad Rayhan Maulana Anas',
#    'link': 'https://stackoverflow.com/users/19808937/muhammad-rayhan-maulana-anas'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006670,
#   'creation_date': 1661006625,
#   'last_edit_date': 1661006670,
#   'question_id': 73427595,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427595/cant-find-a-route-for-post-upload-edit-on-codeigniter-4',
#   'title': 'Can&#39;t find a route for &#39;post: upload/edit&#39;. on codeigniter 4'},
#  {'tags': ['r', 'dictionary', 'data.table'],
#   'owner': {'account_id': 8123589,
#    'reputation': 1564,
#    'user_id': 6119375,
#    'user_type': 'registered',
#    'accept_rate': 50,
#    'profile_image': 'https://www.gravatar.com/avatar/1ed6f6a7573d5ef7a8e9b4789c0c514b?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Nneka',
#    'link': 'https://stackoverflow.com/users/6119375/nneka'},
#   'is_answered': False,
#   'view_count': 19,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661006668,
#   'creation_date': 1661005676,
#   'question_id': 73427488,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427488/map-function-in-r-in-data-table',
#   'title': 'map function in R in data.table'},
#  {'tags': ['python', 'pandas'],
#   'owner': {'account_id': 16979192,
#    'reputation': 21,
#    'user_id': 14972444,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mAwEpbs0TVx_fefJBmL-d9WzjEGnX_3-3gnjEWJiQ=k-s256',
#    'display_name': 'Lucas Vital',
#    'link': 'https://stackoverflow.com/users/14972444/lucas-vital'},
#   'is_answered': False,
#   'view_count': 19,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661006663,
#   'creation_date': 1661001170,
#   'last_edit_date': 1661006663,
#   'question_id': 73426986,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73426986/my-custom-group-by-range-function-is-not-working-as-expected',
#   'title': 'My custom &quot;group by range&quot; function is not working as expected'},
#  {'tags': ['windows', 'git', 'msysgit'],
#   'owner': {'account_id': 1970832,
#    'reputation': 257,
#    'user_id': 1769839,
#    'user_type': 'registered',
#    'accept_rate': 76,
#    'profile_image': 'https://www.gravatar.com/avatar/a8c4ba5573f9da7fd0724e015b5bb243?s=256&d=identicon&r=PG',
#    'display_name': 'jimeast',
#    'link': 'https://stackoverflow.com/users/1769839/jimeast'},
#   'is_answered': True,
#   'view_count': 651,
#   'accepted_answer_id': 21506075,
#   'answer_count': 2,
#   'score': 1,
#   'last_activity_date': 1661006662,
#   'creation_date': 1391298629,
#   'last_edit_date': 1391315430,
#   'question_id': 21505240,
#   'content_license': 'CC BY-SA 3.0',
#   'link': 'https://stackoverflow.com/questions/21505240/trying-to-setup-a-new-editor-in-git',
#   'title': 'Trying to setup a new editor in git'},
#  {'tags': ['node.js', 'amazon-web-services', 'amazon-s3', 'web', 'aws-lambda'],
#   'owner': {'account_id': 18443073,
#    'reputation': 17,
#    'user_id': 13435176,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/863038f7fe0ad57d4c35a43cecdde05f?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'J.Fasterling',
#    'link': 'https://stackoverflow.com/users/13435176/j-fasterling'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1661006658,
#   'creation_date': 1661006658,
#   'question_id': 73427601,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73427601/how-to-provide-a-download-link-to-a-file-which-is-uploaded-to-a-s3-bucket',
#   'title': 'How to provide a download link to a file which is uploaded to a S3 bucket?'}]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
for i in results["items"]:
    if "python" in (i["tags"]):
        print(i["title"])
# Out:
# how can i solve this proplem with python tkniter
# My custom &quot;group by range&quot; function is not working as expected

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
for i in results["items"]:
     if "question_id"=="6784" and "question_id"=="6473":
        print('True')
else:
        print("False")
# Out:
# False
