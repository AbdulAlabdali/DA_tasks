# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'/Users/abdulrahmanalabdali/Desktop/example_data_cleaning.xlsx')
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               1     34982  2013.000000    12900      Student          78
# 1               2     34983  2015.000000     1230       barmen          78
# 2               3     34984  1945.000000     3450      student          78
# 3               4     34985  1923.000000     5670      manager          78
# 4               5     34986  1978.000000     7890           hr          78
# 5               6     34987  1967.000000    10110      Manager          78
# 6              15     34987  1967.000000    30090      Manager          78
# 7              22     34987          NaN    18990       sailer          78
# 8               7     34988          NaN    12330      Manager          78
# 9              23     34988  1999.000000    25650      Manager          78
# 10              8     34989  1958.000000    14550           HR          78
# ...

# %%
df.isnull().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        2
# Amount           0
# Profession       2
# Department       0
# Risk             0
# dtype: int64

# %%
df.drop(columns='Department', inplace=True)

# %%
for col in df.select_dtypes(include=["object"]).columns:
    df[col]=df[col].str.upper()

# %%
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession    Risk
# 0               1     34982  2013.000000    12900      STUDENT     LOW
# 1               2     34983  2015.000000     1230       BARMEN    HIGH
# 2               3     34984  1945.000000     3450      STUDENT  MEDIUM
# 3               4     34985  1923.000000     5670      MANAGER     LOW
# 4               5     34986  1978.000000     7890           HR    HIGH
# 5               6     34987  1967.000000    10110      MANAGER  MEDIUM
# 6              15     34987  1967.000000    30090      MANAGER     LOW
# 7              22     34987          NaN    18990       SAILER    HIGH
# 8               7     34988          NaN    12330      MANAGER  MEDIUM
# 9              23     34988  1999.000000    25650      MANAGER     LOW
# 10              8     34989  1958.000000    14550           HR    HIGH
# 11             24     34989  1967.000000    27870           HR  MEDIUM
# ...

# %%
df.loc[df['Profession']=='ETUDIENT','Profession']='STUDENT'

# %%
df=df[(df['BirthYear']<2004) & (df['BirthYear']>1922)]
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession    Risk
# 2               3     34984  1945.000000     3450      STUDENT  MEDIUM
# 3               4     34985  1923.000000     5670      MANAGER     LOW
# 4               5     34986  1978.000000     7890           HR    HIGH
# 5               6     34987  1967.000000    10110      MANAGER  MEDIUM
# 6              15     34987  1967.000000    30090      MANAGER     LOW
# 9              23     34988  1999.000000    25650      MANAGER     LOW
# 10              8     34989  1958.000000    14550           HR    HIGH
# 11             24     34989  1967.000000    27870           HR  MEDIUM
# 12              9     34990  1953.285714    16770      MANAGER  MEDIUM
# 13             10     34991  1988.000000    18990          BDM     LOW
# 14             30     34991  1988.000000    55250          BDM    HIGH
# 15             11     34992  1943.857143    21210   RESEARCHER  MEDIUM
# ...

# %%
df=df[df['Amount']<(1000000)]
df
# Out:
#     TransactionID  ClientID    BirthYear  Amount   Profession    Risk
# 2               3     34984  1945.000000    3450      STUDENT  MEDIUM
# 3               4     34985  1923.000000    5670      MANAGER     LOW
# 4               5     34986  1978.000000    7890           HR    HIGH
# 5               6     34987  1967.000000   10110      MANAGER  MEDIUM
# 6              15     34987  1967.000000   30090      MANAGER     LOW
# 9              23     34988  1999.000000   25650      MANAGER     LOW
# 10              8     34989  1958.000000   14550           HR    HIGH
# 11             24     34989  1967.000000   27870           HR  MEDIUM
# 12              9     34990  1953.285714   16770      MANAGER  MEDIUM
# 13             10     34991  1988.000000   18990          BDM     LOW
# 14             30     34991  1988.000000   55250          BDM    HIGH
# 15             11     34992  1943.857143   21210   RESEARCHER  MEDIUM
# ...

# %%
import sklearn as sk
from sklearn import datasets

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_enc = OrdinalEncoder()
df["Risk_code"] = ord_enc.fit_transform(df[["Risk"]])
df[["Risk", "Risk_code"]]
df
# Out:
# /var/folders/_3/p7g0czqs2mn2vrf8z2svm6ph0000gn/T/ipykernel_81077/4209448752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Risk_code"] = ord_enc.fit_transform(df[["Risk"]])
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk  Risk_code
# 2               3     34984       1945    3450      STUDENT  MEDIUM        2.0
# 3               4     34985       1923    5670      MANAGER     LOW        1.0
# 4               5     34986       1978    7890           HR    HIGH        0.0
# 5               6     34987       1967   10110      MANAGER  MEDIUM        2.0
# 6              15     34987       1967   30090      MANAGER     LOW        1.0
# ...
